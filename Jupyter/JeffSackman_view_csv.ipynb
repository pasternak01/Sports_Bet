# %%
import pandas as pd
import requests

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JeffSackmann/tennis_slam_pointbypoint/refs/heads/master/2015-ausopen-points.csv")

# %%
df
# Out:
#                 match_id ElapsedTime  SetNo  P1GamesWon  P2GamesWon  \
# 0      2015-ausopen-1101     0:00:00    1.0         0.0         0.0
# 1      2015-ausopen-1101     0:00:00    1.0         0.0         0.0
# 2      2015-ausopen-1101     0:00:18    1.0         0.0         0.0
# 3      2015-ausopen-1101     0:00:50    1.0         0.0         0.0
# 4      2015-ausopen-1101     0:01:22    1.0         0.0         0.0
# ...                  ...         ...    ...         ...         ...
# 38304  2015-ausopen-2701     1:47:07    2.0         6.0         6.0
# 38305  2015-ausopen-2701     1:48:04    2.0         6.0         6.0
# 38306  2015-ausopen-2701     1:48:48    2.0         6.0         6.0
# 38307  2015-ausopen-2701     1:49:35    2.0         6.0         6.0
# 38308  2015-ausopen-2701     1:51:12    2.0         7.0         6.0
#
#        SetWinner  GameNo  GameWinner  PointNumber  PointWinner  ...  \
# 0              0     1.0           0            0          0.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38309 entries, 0 to 38308
# Data columns (total 59 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   match_id            38309 non-null  object
#  1   ElapsedTime         38309 non-null  object
#  2   SetNo               38308 non-null  float64
#  3   P1GamesWon          38308 non-null  float64
#  4   P2GamesWon          38308 non-null  float64
#  5   SetWinner           38309 non-null  int64
#  6   GameNo              38308 non-null  float64
#  7   GameWinner          38309 non-null  int64
#  8   PointNumber         38309 non-null  int64
#  9   PointWinner         38308 non-null  float64
#  10  PointServer         38308 non-null  float64
#  11  Speed_KMH           38308 non-null  float64
#  12  Rally               0 non-null      float64
#  13  P1Score             38308 non-null  object
#  14  P2Score             38308 non-null  object
# ...

# %%
df.describe()
# Out:
#               SetNo    P1GamesWon    P2GamesWon     SetWinner        GameNo  \
# count  38308.000000  38308.000000  38308.000000  38309.000000  38308.000000
# mean       2.129999      2.373290      2.357915      0.024485      5.574632
# std        1.071839      1.804253      1.834967      0.200828      3.229024
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        1.000000      1.000000      1.000000      0.000000      3.000000
# 50%        2.000000      2.000000      2.000000      0.000000      5.000000
# 75%        3.000000      4.000000      4.000000      0.000000      8.000000
# max        5.000000     10.000000      8.000000      2.000000     18.000000
#
#          GameWinner   PointNumber   PointWinner   PointServer     Speed_KMH  \
# count  38309.000000  38309.000000  38308.000000  38308.000000  38308.000000
# mean       0.234958    102.980475      1.492404      1.494675    127.737444
# ...

# %%
df.isnull().sum()
# Out:
# match_id                  0
# ElapsedTime               0
# SetNo                     1
# P1GamesWon                1
# P2GamesWon                1
# SetWinner                 0
# GameNo                    1
# GameWinner                0
# PointNumber               0
# PointWinner               1
# PointServer               1
# Speed_KMH                 1
# Rally                 38309
# P1Score                   1
# P2Score                   1
# P1Momentum            38309
# P2Momentum            38309
# P1PointsWon               1
# P2PointsWon               1
# P1Ace                     0
# P2Ace                     0
# P1Winner                  0
# P2Winner                  0
# P1DoubleFault             0
# P2DoubleFault             0
# P1UnfErr                  0
# P2UnfErr                  0
# P1NetPoint                0
# P2NetPoint                0
# P1NetPointWon             0
# P2NetPointWon             0
# P1BreakPoint              0
# P2BreakPoint              0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\_Programming\Sports_Bet\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['player1'].value_counts()
#
# ...
